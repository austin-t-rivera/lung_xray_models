# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
import pickle

#Set directory
current_directory_path = r"C:\\Users\\atr8e/OneDrive/Documents/MSDS/2024_Spring/DS_6050/Project/Milestone_3/Models_and_Datasets/Four_Class_Model/"
os.chdir(current_directory_path)

# ML Libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Load Preprocessed Data

# %%
# Set path to the data and models
dataset_dir = r"C:\\Users\\atr8e/OneDrive/Documents/MSDS/2024_Spring/DS_6050/Project/Milestone_3/Models_and_Datasets/Four_Class_Model/"

# Iterate through files in the folder
for file_name in os.listdir(dataset_dir):
    # Check if the file has .pkl extension
    if file_name.endswith('unbalanced.pkl'):
        # Load the pickle file
        file_path = os.path.join(dataset_dir, file_name)
        with open(file_path, 'rb') as file:
            images, labels = pickle.load(file)
            
        # Convert to numpy arrays
        images, labels = np.array(images), np.array(labels)
        
        # Assign loaded data to variables with modified names
        # Remove .pkl extension from the file name
        variable_name = os.path.splitext(file_name)[0]
        # Remove the unbalanced part of the file name
        variable_name = variable_name[:-11]
        # Assign loaded data to variables with modified names
        globals()[f"{variable_name}_images"] = images
        globals()[f"{variable_name}_labels"] = labels

        # Optionally, you can print the loaded data for verification
        print(f"Loaded {variable_name}_images with length {images.shape}")
        print(f"Loaded {variable_name}_labels with length {len(labels)}")
# Out:
# Loaded four_class_test_images with length (1253, 256, 256)
# Loaded four_class_test_labels with length 1253
# Loaded four_class_train_images with length (10004, 256, 256)
# Loaded four_class_train_labels with length 10004
# Loaded four_class_val_images with length (1250, 256, 256)
# Loaded four_class_val_labels with length 1250

# %% [markdown]
# # Four-Class Model

# %%
num_classes = 4
img_height = 256
img_width = 256
input_shape = (256, 256, 1)

# %%
FC_model = Sequential([
    layers.Input(shape=input_shape),
    layers.Conv2D(6, (5, 5), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(16, (5, 5), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(120, activation='relu'),
    layers.Dense(84, activation='relu'),
    layers.Dense(num_classes, activation='sigmoid')
])

# %%
FC_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
FC_history = FC_model.fit(four_class_train_images, four_class_train_labels,
                          epochs=10,
                          batch_size=32,
                          validation_data=(four_class_val_images, four_class_val_labels))
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.6626 - loss: 9.3984 - val_accuracy: 0.7680 - val_loss: 0.6185
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - accuracy: 0.8073 - loss: 0.4406 - val_accuracy: 0.7864 - val_loss: 0.6932
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.7874 - loss: 0.4623 - val_accuracy: 0.7920 - val_loss: 0.6752
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - accuracy: 0.8385 - loss: 0.3281 - val_accuracy: 0.6720 - val_loss: 0.8428
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 82ms/step - accuracy: 0.7206 - loss: 0.6828 - val_accuracy: 0.7472 - val_loss: 0.6427
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - accuracy: 0.7846 - loss: 0.4709 - val_accuracy: 0.7296 - val_loss: 0.6390
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - accuracy: 0.8227 - loss: 0.3592 - val_accuracy: 0.7576 - val_loss: 0.7630
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step - accuracy: 0.8413 - loss: 0.3048 - val_accuracy: 0.7792 - val_loss: 0.7081
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.8475 - loss: 0.2927 - val_accuracy: 0.7456 - val_loss: 0.7273
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 92ms/step - accuracy: 0.8486 - loss: 0.2700 - val_accuracy: 0.7000 - val_loss: 0.8151

# %%
epochs = 10
acc = FC_history.history['accuracy']
val_acc = FC_history.history['val_accuracy']

loss = [min([x, 1]) for x in FC_history.history['loss']]
val_loss = [min([x, 1]) for x in FC_history.history['val_loss']]

#loss = [min([x, 1]) for x in loss]

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_loss, test_accuracy = FC_model.evaluate(four_class_test_images, four_class_test_labels)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8943 - loss: 0.2921
# Test Loss: 0.6807143092155457
# Test Accuracy: 0.7110933661460876

# %%
#FC_model.summary()

# %% [markdown]
# # Save the model and training history

# %%
# Specify the file path where you want to save the model
model_save_path = r"C:\\Users\\atr8e/OneDrive/Documents/MSDS/2024_Spring/DS_6050/Project/Milestone_3/Models_and_Datasets/Four_Class_Model/Unbalanced_FC_model.keras"

# Save the trained model to the specified file path
FC_model.save(model_save_path)

print("Model saved successfully at:", model_save_path)
# Out:
# Model saved successfully at: C:\\Users\\atr8e/OneDrive/Documents/MSDS/2024_Spring/DS_6050/Project/Milestone_3/Models_and_Datasets/Four_Class_Model/Unbalanced_FC_model.keras
